# %%
# Importing packages
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
import seaborn as sns

# %%
# Reading the data
df=pd.read_csv("Unit04 Global_Population.csv")
df2=pd.read_csv("Unit04 Global_GDP.csv")

# %%
# Exploring the data
df.head(10)
# Out:
#                   Country Name Country Code        Series Name  Series Code  \
# 0                        Aruba          ABW  Population, total  SP.POP.TOTL
# 1                  Afghanistan          AFG  Population, total  SP.POP.TOTL
# 2  Africa Eastern and Southern          AFE  Population, total  SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total  SP.POP.TOTL
# 4                      Albania          ALB  Population, total  SP.POP.TOTL
# 5                      Algeria          DZA  Population, total  SP.POP.TOTL
# 6               American Samoa          ASM  Population, total  SP.POP.TOTL
# 7                      Andorra          AND  Population, total  SP.POP.TOTL
# 8                       Angola          AGO  Population, total  SP.POP.TOTL
# 9          Antigua and Barbuda          ATG  Population, total  SP.POP.TOTL
#
#         1960       1961       1962       1963       1964       1965  ...  \
# ...

# %%
df2.head(10)
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
# 5                      Albania          ALB  GDP (current US$)
# 6                      Andorra          AND  GDP (current US$)
# 7                   Arab World          ARB  GDP (current US$)
# 8         United Arab Emirates          ARE  GDP (current US$)
# 9                    Argentina          ARG  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  1.929944e+10  1.970954e+10  2.147872e+10  2.571501e+10
# ...

# %%
# Filling missing values
year_cols = [str(year) for year in range(2001, 2022)]
year_cols2 = [str(year) for year in range(2001, 2021)]

# Converting population data to numeric
df[year_cols] = df[year_cols].apply(pd.to_numeric, errors='coerce')
df2[year_cols2] = df2[year_cols2].apply(pd.to_numeric, errors='coerce')

# %%
# Filling missing values in each row with the row mean
df[year_cols] = df[year_cols].apply(lambda row: row.fillna(row.mean()), axis=1)

# Computing mean population
df['Mean_Population'] = df[year_cols].mean(axis=1)

# Filling missing values in each row with the row mean
df2[year_cols2] = df2[year_cols2].apply(lambda row: row.fillna(row.mean()), axis=1)

# Computing mean GDP per capita
df2['Mean_PerCapita_GDP'] = df2[year_cols2].mean(axis=1)

# %%
# Exploring the new data frame
merged_df.head()
# Out:
#                   Country Name  Mean_Population  Mean_PerCapita_GDP
# 0                        Aruba     1.014995e+05        2.553357e+09
# 1                  Afghanistan     3.067118e+07        1.402300e+10
# 2  Africa Eastern and Southern     5.398680e+08        7.441522e+11
# 3   Africa Western and Central     3.647774e+08        5.570494e+11
# 4                      Albania     2.930953e+06        1.092357e+10

# %%
# Dropping rows with NaN in either column
clean_df = merged_df.dropna(subset=['Mean_Population', 'Mean_PerCapita_GDP'])

# %%
import matplotlib.pyplot as plt

# Creating a scatter plot of GDP vs population
plt.scatter(clean_df['Mean_Population'], clean_df['Mean_PerCapita_GDP'], color = 'black')
plt.xlabel("Mean Population (2001-2021)")
plt.ylabel("Mean GDP per Capita (2001-2021)")
plt.title("Population vs GDP per Capita")
plt.show()

# Saving figure
plt.savefig("population_vs_gdp.png", dpi=300, bbox_inches='tight')  # dpi=300 for high quality

# %%
# Seeing how many rows were dropped
print("Original rows:", len(merged_df))
print("Rows after dropping NaNs:", len(clean_df))
# Out:
# Original rows: 267
# Rows after dropping NaNs: 257

# %%
# Outputting which rows were dropped
dropped_rows = merged_df[merged_df[['Mean_Population','Mean_PerCapita_GDP']].isna().any(axis=1)]
print(dropped_rows)
# Out:
#                   Country Name  Mean_Population  Mean_PerCapita_GDP
# 31      British Virgin Islands     2.675529e+04                 NaN
# 85            French Polynesia     2.668708e+05                 NaN
# 91                   Gibraltar     3.338410e+04                 NaN
# 106                  IBRD only              NaN        1.953153e+13
# 109                  IDA blend              NaN        6.942384e+11
# 110                   IDA only              NaN        2.641647e+12
# 111                  IDA total              NaN        3.331938e+12
# 126  Korea, Dem. People's Rep.     2.464031e+07                 NaN
# 184             Not classified              NaN                 NaN
# 228   St. Martin (French part)     3.564165e+04                 NaN

# %%
# Computing Pearson correlation
from scipy.stats import pearsonr
corr, p_value = pearsonr(clean_df['Mean_Population'], clean_df['Mean_PerCapita_GDP'])

print("Pearson correlation coefficient:", corr)
print("p-value:", p_value)
# Out:
# Pearson correlation coefficient: 0.7206892549668809
# p-value: 1.850046539909223e-42

# %%
# Train-test data preparation
msk=np.random.rand(len(clean_df))<0.8
train=clean_df[msk]
test=clean_df[~msk]

# %%
# Using sklearn package for data modelling
from sklearn import linear_model
regr=linear_model.LinearRegression()
train_x=np.asanyarray(train[['Mean_Population']], dtype=float)
train_y=np.asanyarray(train[['Mean_PerCapita_GDP']], dtype=float)

regr.fit(train_x, train_y)
# The coefficients
print('Coefficients:', regr.coef_)
print('Intercept:', regr.intercept_)
# Out:
# Coefficients: [[6457.04741731]]
# Intercept: [2.90219519e+11]

# %%
# Plotting outputs
plt.scatter(train.Mean_Population,train.Mean_PerCapita_GDP,color='blue')
plt.plot(train_x,regr.coef_[0][0]*train_x + regr.intercept_[0],'-r')
plt.xlabel("Mean_Population")
plt.ylabel("Mean_PerCapita_GDP")
# Scatter plot of Mean Population vs Mean Per Capita GDP with fitted linear regression line
plt.savefig("linreg.png", dpi=300, bbox_inches='tight')  # dpi=300 for high quality

# %%
# Model evaluation
from sklearn.metrics import r2_score
test_x=np.asanyarray(test[['Mean_Population']])
test_y=np.asanyarray(test[['Mean_PerCapita_GDP']])
test_y_ = regr.predict(test_y)

# %%
print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_-test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_-test_y)**2))
print("R2-score: %.2f" % r2_score(test_y_,test_y))
# Out:
# Mean absolute error: 17347363161432354.00
# Residual sum of squares (MSE): 2374553208662255567689317118640128.00
# R2-score: -0.14
